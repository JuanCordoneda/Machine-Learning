# %% [markdown]
# ![Logo-Instituto-Data-Science-Movil.png.webp](data:image/webp;base64,...) https://institutodatascience.org/

# %% [markdown]
# **Resuelva los ejemplos solicitados**

# %% [markdown]
# suma de tensores

# %%
import torch

# Crear dos tensores


# Sumar los tensores

# %% [markdown]
# resta

# %%
import torch

# Crear dos tensores

# Restar los tensores

# %%
#Multiplicación de Tensores por Escalar:

import torch

# Crear un tensor

# Multiplicar el tensor por un escalar

# %%
#producto
import torch

# Crear dos tensores

# Calcular el producto punto

# %%
#Multiplicación de Elementos de Tensores:
import torch

# Crear dos tensores


# Multiplicar elemento por elemento

# %%
#División de Tensores por Escalar:
import torch

# Crear un tensor


# Dividir el tensor por un escalar

# %%
#Raiz cuadrada
import torch

# Crear un tensor

# Calcular la raíz cuadrada del tensor

# %% [markdown]
# Redondeo

# %%
import torch

# Crear un tensor con números decimales


# Redondear los elementos del tensor

# %% [markdown]
# Conversión de Numpy a Tensor:

# %%
import torch
import numpy as np

# Crear un arreglo Numpy

# Convertir Numpy array a tensor

# %% [markdown]
# Conversión de Tensor a Numpy:

# %%
import torch
import numpy as np

# Crear un tensor


# Convertir tensor a Numpy array

# %% [markdown]
# Uso de detach para Obtener un Tensor Independiente:

# %%
import torch

#x = torch.tensor([2.0], requires_grad=True)
#y = x**2 + 3*x + 1
