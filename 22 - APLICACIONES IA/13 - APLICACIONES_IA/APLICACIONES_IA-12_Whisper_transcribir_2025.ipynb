# %% [markdown]
# [FUENTE](https://www.youtube.com/watch?v=4rP8uCzDgcE)

# %% [markdown]
# ### Configuración de Whisper

# %%
# !pip freeze > requirements.txt

# %%
# !pip list | grep ffmpeg
# Out:
# imageio-ffmpeg                        0.6.0

# %% [markdown]
# **1. Instalamos API**

# %%
#Instalamos librerias de OpenAI
#!pip install openai
#dependencias adicionales para soportar formatos
# !apt-get install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %% [markdown]
# **2. Importamos librerías**

# %%
# Importamos librerías instaladas
from openai import OpenAI
import os

# %% [markdown]
# **3. Autenticación con la API**

# %%
# Open AI API-key
from google.colab import files
from IPython.display import clear_output

files.upload() # subir archivo con apikey de openai propio
clear_output() # no muestra contenido del apikey

# %%
# !ls
# Out:
# idsa_openai_key.txt  requirements.txt  sample_data

# %%
def get_api_key():
    with open('idsa_openai_key.txt', 'r') as fp: #acá reemplazar x el nombre de tu archivo
        key = fp.read()
    return key

# Enter your OpenAI API key here
OPENAI_API_KEY = get_api_key()

# %%
# Configuramos el cliente con la clave guardada
client = OpenAI(api_key=OPENAI_API_KEY)

# Comprobamos que la clave funciona correctamente
print("Clave API establecida correctamente y cliente configurado.")
# Out:
# Clave API establecida correctamente y cliente configurado.

# %% [markdown]
# ### Audio a texto

# %% [markdown]
# **4. Creamos una función de transcripción**

# %%
def transcribe_audio(cliente, ruta_archivo):
    # Abre el archivo de audio en modo lectura binaria ('rb' significa read binary)
    # Esto es necesario para poder enviar el archivo en formato correcto a la API
    archivo_audio = open(ruta_archivo, "rb")

    # Llama a la API del cliente Whisper para transcribir el archivo de audio
    # `cliente.audio.transcriptions.create` es el método que envía el archivo a la API de Whisper
    # Se le pasa el modelo de Whisper a utilizar ("whisper-1") y el archivo de audio
    transcripcion = cliente.audio.transcriptions.create(
        model="whisper-1",  # Especifica el modelo de Whisper a usar
        file=archivo_audio  # El archivo de audio abierto se pasa aquí
    )

    # Devuelve el resultado de la transcripción generado por la API de Whisper
    return transcripcion

# %%
# Descargar archivo de prueba
# !wget https://github.com/palasatenea66/DATASETS/raw/main/prueba_whisper.mp3
# Out:
# --2025-08-05 00:40:29--  https://github.com/palasatenea66/DATASETS/raw/main/prueba_whisper.mp3
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/palasatenea66/DATASETS/main/prueba_whisper.mp3 [following]
# --2025-08-05 00:40:29--  https://raw.githubusercontent.com/palasatenea66/DATASETS/main/prueba_whisper.mp3
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1174605 (1.1M) [audio/mpeg]
# Saving to: ‘prueba_whisper.mp3’
#
# prueba_whisper.mp3  100%[===================>]   1.12M  --.-KB/s    in 0.01s
#
# 2025-08-05 00:40:29 (101 MB/s) - ‘prueba_whisper.mp3’ saved [1174605/1174605]

# %%
# !ls
# Out:
# idsa_openai_key.txt  prueba_whisper.mp3  requirements.txt  sample_data

# %% [markdown]
# El texto grabado :-->
# ' Este es un mensaje de prueba para probar la transcripción de Whisper. Les leo.
# En la INDIA se enseñan las "Cuatro Leyes de la Espiritualidad".
# La primera dice: "La persona que llega es la persona correcta", es decir que nadie llega a nuestras vidas por casualidad, todas las personas que nos rodean, que interactúan con nosotros, están allí por algo, para hacernos aprender y avanzar en cada situación.
# La segunda ley dice: "Lo que sucede es la única cosa que podía haber sucedido". Nada, pero nada, absolutamente nada de lo que nos sucede en nuestras vidas podría haber sido de otra manera. Ni siquiera el detalle más insignificante. No existe el: "si hubiera hecho tal cosa hubiera sucedido tal otra...". No. Lo que pasó fue lo único que pudo haber pasado, y tuvo que haber sido así para que aprendamos esa lección y sigamos adelante. Todas y cada una de las situaciones que nos suceden en nuestras vidas son perfectas, aunque nuestra mente y nuestro ego se resistan y no quieran aceptarlo.
# La tercera dice: "En cualquier momento que comience es el momento correcto". Todo comienza en el momento indicado, ni antes, ni después. Cuando estamos preparados para que algo nuevo empiece en nuestras vidas, es allí cuando comenzará.
# Y la cuarta y última: "Cuando algo termina, termina". Simplemente así. Si algo terminó en nuestras vidas, es para nuestra evolución, por lo tanto es mejor dejarlo, seguir adelante y avanzar ya enriquecidos con esa experiencia.
# Creo que no es casual que estén leyendo esto, si este texto llegó a nuestras vidas hoy; es porque estamos preparados para entender que ningún copo de nieve cae alguna vez en el lugar equivocado" '

# %% [markdown]
# **4. Creamos una función de transcripción**

# %%
# Le pasamos el archivo de audio
transcripcion_1 = transcribe_audio(client, "prueba_whisper.mp3")
transcripcion_1

# Pasamos a texto
transcripcion_1.text
# Out:
# 'Este es un mensaje de prueba para aprobar la transcripción de Whisper. Les leo. En la India se enseñan las cuatro leyes de la espiritualidad. La primera dice, la persona que llega es la persona correcta. Es decir, que nadie llega a nuestras vidas por casualidad, todas las personas que nos rodean, que interactúan con nosotros, están allí por algo para hacernos aprender y avanzar en cada situación. La segunda ley dice, lo que sucede es la única cosa que podía haber sucedido. Nada, pero nada, absolutamente nada de lo que nos sucede en nuestras vidas, podría haber sido de otra manera, ni siquiera el detalle más insignificante. No existe el, si hubiera hecho tal cosa, hubiera sucedido tal otra. No. Lo que pasó fue lo único que pudo haber pasado y tuvo que haber sido así para que aprendamos esa lección y sigamos adelante. Todas y cada una de las situaciones que nos suceden en nuestras vidas son perfectas, aunque nuestra mente y nuestro ego se resistan y no quieran aceptarlo. La tercera dice, en cualquier momento que comience, es el momento correcto. Todo comienza en el momento indicado, ni antes ni después. Cuando estamos preparados para que algo nuevo empiece en nuestras vidas, es allí cuando comenzará. Y la cuarta y última, cuando algo termina, termina. Simplemente así. Si algo termina en nuestras vidas, es para nuestra evolución, por lo tanto es mejor dejarlo, seguir adelante y avanzar ya enriquecidos con esa experiencia. Creo que no es casual que estén leyendo esto. Si este texto llegó a nuestras vidas hoy, es porque estamos preparados para entender que ningún copo de nieve cae alguna vez en el lugar equivocado.'

# %% [markdown]
# ### Transcribiendo a otros idiomas

# %% [markdown]
# **6. Ahora creamos función de traducción de audio a texto**

# %%
def traduce_audio_a_ingles(cliente, ruta_archivo):
    # Define una función llamada 'traduce_audio_a_ingles' que toma dos argumentos:
    # 'cliente' (el cliente que interactúa con el servicio de traducción de audio) y
    # 'ruta_archivo' (la ruta donde se encuentra el archivo de audio que se quiere traducir).

    archivo_audio = open(ruta_archivo, "rb")
    # Abre el archivo de audio ubicado en 'ruta_archivo' en modo de lectura binaria ("rb").
    # Esto es necesario para trabajar con archivos de audio ya que suelen almacenarse en formato binario.
    # 'archivo_audio' ahora contiene una referencia al archivo abierto.

    traduccion = cliente.audio.translations.create(
        model="whisper-1",
        file=archivo_audio) #, language='french'

    # Utiliza el cliente proporcionado (posiblemente una instancia de la API de OpenAI u otro servicio)
    # para crear una traducción del archivo de audio.
    # La llamada 'cliente.audio.translations.create' usa el modelo "whisper-1" para hacer la traducción.
    # 'file=archivo_audio' pasa el archivo de audio abierto como entrada para el proceso de traducción.
    # El resultado de la traducción (probablemente texto traducido del audio) se almacena en la variable 'traduccion'.

    return traduccion
    # Finalmente, la función devuelve el resultado de la traducción.

# %%
#Ejecuto la función
traduccion_1 = traduce_audio_a_ingles(client, "prueba_whisper.mp3")
traduccion_1
# Out:
# Translation(text='This is a test message to approve the transcription of Whisper. I read them. In India, the four laws of spirituality are taught. The first says, the person who arrives is the right person. That is, no one arrives in our lives by chance. All the people who surround us, who interact with us, are there for a reason, to make us learn and advance in each situation. The second law says, what happens is the only thing that could have happened. Nothing, but nothing, absolutely nothing, of what happens to us in our lives could have been otherwise. Not even the most insignificant detail. There is no such thing as, if I had done such a thing, such a thing would have happened. No, what happened was the only thing that could have happened and had to have been so that we learn that lesson and move on. Each and every situation that happens to us in our lives is perfect, although our mind and our ego resist and do not want to accept it. The third says, at any time that begins is the right time. Everything begins at the right time, neither before nor after. When we are prepared for something new to begin in our lives, that is when it will begin. And the fourth and last, when something ends, it ends. Just like that. If something ends in our lives, it is for our evolution, therefore it is better to leave it, move on and advance already enriched with that experience. I think it is no coincidence that you are reading this. If this text came to our lives today, it is because we are prepared to understand that no snowflake ever falls in the wrong place.')

# %% [markdown]
# ### [Ejemplo de fine tuning para otro idioma: hindi](https://colab.research.google.com/github/sanchit-gandhi/notebooks/blob/main/fine_tune_whisper.ipynb#scrollTo=7f737783-2870-4e35-aa11-86a42d7d997a)
