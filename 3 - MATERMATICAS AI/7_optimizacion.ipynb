# %% [markdown]
# # 📌 Optimización en Matemáticas
#
# ## 🎯 ¿Qué es?
# La optimización es el proceso de encontrar los **máximos o mínimos** de una función, llamada **función objetivo**, posiblemente sujeta a **restricciones**.
#
# ## 🔢 Función Objetivo
# - Es la función que se quiere maximizar o minimizar.
# - Notación común:
#   f(mathbf{x}) = f(x_1, x_2, \ldots, x_n)
#
#   donde ( \mathbf{x} ) son las **variables de decisión**.
#
# ## 🧠 ¿Cómo se encuentran máximos y mínimos?
# - Se utilizan **derivadas** para hallar:
#   - **Puntos críticos**: donde la derivada se anula.
#   - **Puntos en los bordes del dominio**.
# - Luego se analiza si se trata de un **máximo**, **mínimo** o **punto de inflexión**.
#
# ## 🛠️ Proceso de Optimización
# - Métodos comunes:
#   - **Analíticos**: con cálculo diferencial.
#   - **Numéricos**: como el **gradiente descendente** (utilizado en machine learning).

# %% [markdown]
# # 📌 Optimización en Deep Learning
#
# ## 🎯 ¿Por qué es importante?
# La **optimización** es clave en deep learning y machine learning, ya que permite que los modelos **aprendan** ajustando sus parámetros para realizar buenas predicciones.
#
# ## ⚙️ Ajuste de Parámetros
# Los modelos de deep learning tienen **muchos parámetros** (pesos) que deben ajustarse para minimizar el error en las predicciones.
# 👉 La optimización busca los **valores óptimos** de esos parámetros.
#
# ## 🧠 Redes Neuronales
# - Las redes ajustan los **pesos sinápticos** entre neuronas.
# - Usan **descenso de gradiente** u otros métodos para minimizar la **función de pérdida** y mejorar la precisión.
#
# ## 📚 Aprendizaje Supervisado
# - El modelo aprende a mapear entradas a salidas conocidas.
# - La optimización ajusta el modelo para que las predicciones **se acerquen lo más posible** a los valores reales.
#
# ## 🧱 Aprendizaje Profundo
# - Los modelos profundos tienen **muchas capas**.
# - La optimización es vital para que **todas las capas** contribuyan correctamente al aprendizaje.
#
# ## 🧩 Consideraciones Clave
# - Seleccionar algoritmos de optimización eficientes.
# - Manejar **problemas comunes** como:
#   - **Overfitting** (sobreajuste)
#   - **Mínimos locales**
#   - **Desvanecimiento/explosión del gradiente**
#
# ✅ En resumen:
# La optimización permite que los modelos **aprendan de los datos**, ajustando sus parámetros para **generalizar** correctamente a nuevos ejemplos.

# %% [markdown]
# # 🚗 Ejemplo Numérico de Optimización en la Vida Cotidiana
#
# ## 🎯 Objetivo
# Minimizar el **tiempo total de viaje** entre tu casa y el trabajo.
#
# ## 📐 Datos del problema
# - 📏 Distancia fija: `d = 20 km`
# - 🏎️ Velocidad variable: `x` (km/h)
# - 🔒 Restricciones:
#   - `x ≥ 0` (no se puede ir en reversa)
#   - `x ≤ 100` (velocidad máxima permitida)
#
# ## 🧠 Función Objetivo
#
# Queremos minimizar el tiempo total de viaje:
#
# f(x) = \frac{20}{x}
#
# Donde:
# - \( d = 20 \) es la distancia en km
# - \( x \) es la velocidad en km/h
#
# ## 📉 Derivada de la Función
#
# Calculamos la derivada para encontrar extremos:
#
# f'(x) = -\frac{20}{x^2}
#
# Buscamos puntos críticos igualando la derivada a cero:
#
# -\frac{20}{x^2} = 0
#
# ⛔ Esto **no tiene solución real**, ya que la derivada nunca se anula (la función siempre decrece en su dominio válido).
#
# ## 🧪 Evaluación en los extremos
#
# Como no hay extremos interiores, evaluamos los **bordes del intervalo permitido** \([0, 100]\):
#
# - \( f(0) \) no está definido (división por cero)
# - \( f(100) = \frac{20}{100} = 0.2 \) horas = **12 minutos**
#
# ## ✅ Conclusión
#
# La **velocidad óptima** que **minimiza el tiempo** dentro del intervalo permitido es:
#
# x = 100 \, \text{km/h} \Rightarrow t = 12 \, \text{minutos}
# Esto demuestra cómo el análisis de derivadas y extremos nos ayuda a resolver problemas cotidianos con herramientas de **optimización matemática**.

# %%
# Ejercicio 1: Minimización de Pérdidas
# Una empresa produce (x) unidades de un artículo y desea minimizar sus pérdidas. La función de pérdida está dada por:

# [ L(x) = 3x^2 + 120x + 500 ]

# Encuentra el valor de (x) que minimiza las pérdidas y comenta sobre la interpretación del resultado en el contexto del problema.

import sympy as sp

# 📌 Variable simbólica
x = sp.symbols('x')

# 📉 Función de pérdida
L = 3*x**2 + 120*x + 500

# 🧮 Derivada (para encontrar extremos)
L_deriv = sp.diff(L, x)

# 🔍 Puntos críticos: donde L' = 0
crit_points = sp.solve(L_deriv, x)

# 🧪 Segunda derivada (clasificación)
L_second_deriv = sp.diff(L_deriv, x)

# ✅ Resultado
optimal_x = crit_points[0]
clasificacion = "mínimo local" if L_second_deriv > 0 else "máximo o indefinido"

# 🖨️ Resultados
print("Función de pérdida:", L)
print("Derivada:", L_deriv)
print("Punto crítico:", optimal_x)
print("Segunda derivada:", L_second_deriv)
print("Clasificación:", clasificacion)

# La segunda derivada se utiliza para determinar la concavidad de la función y, por lo tanto, identificar si el punto crítico encontrado es un mínimo local, 
# un máximo local o un punto de inflexión. En este caso, la segunda derivada es positiva (6), lo que indica que la función de pérdida es cóncava hacia arriba 
# en (x = -20). Esto confirma que (x = -20) corresponde a un mínimo local de la función de pérdida.

# El hecho de que 𝑥 = -20 sea el valor que minimiza las pérdidas significa que, según el modelo matemático, las pérdidas serán más bajas 
# cuando la empresa no produzca ninguna unidad (es decir, 𝑥 = 0). Esto puede interpretarse como una señal de que la empresa podría estar 
# operando en un punto donde la producción actual está generando más pérdidas de lo necesario, y que sería beneficioso administrar mejor producción. 📉🏭💼
# Out:
# Función de pérdida: 3*x**2 + 120*x + 500
# Derivada: 6*x + 120
# Punto crítico: -20
# Segunda derivada: 6
# Clasificación: mínimo local

# %%
# Ejercicio 2: Maximización de Ganancias
# Una tienda vende (y) productos y busca maximizar sus ganancias. La función de ganancias está modelada por:

# G(y) = 15y - 0.2y^2

# Utiliza derivadas para encontrar el valor óptimo de (y) y comenta sobre la interpretación económica del resultado.

import sympy as sp

# Definición de la variable y la función de ganancias
y = sp.symbols('y')
profit_function = 15*y - 0.2*y**2

# Derivada de la función de ganancias
derivative_profit = sp.diff(profit_function, y)
print("Derivada de la función de ganancias:", derivative_profit)

# Puntos críticos (donde la derivada es cero)
critical_points_profit = sp.solve(derivative_profit, y)
print("Puntos críticos de la función de ganancias:", critical_points_profit)

# Segunda derivada para determinar si es un máximo local
second_derivative_profit = sp.diff(derivative_profit, y)
print("Segunda derivada de la función de ganancias:", second_derivative_profit)

# Seleccionamos el punto crítico donde la concavidad es negativa (máximo local)
optimal_y = critical_points_profit[0]  # Como la concavidad es negativa, es el máximo local
print(f"El valor de y que maximiza las ganancias es: {optimal_y}")

# La segunda derivada se utiliza para determinar la concavidad de la función y, por lo tanto, identificar si el punto crítico encontrado es un mínimo local, 
# un máximo local o un punto de inflexión. En este caso, la segunda derivada es negativa (-0.4), lo que indica que la 
# función de ganancias es cóncava hacia abajo en (x = 37.5). Esto confirma que (x = 37.5) corresponde a un máximo local en la función de ganancias.

# Sustituir el valor en la función original de ganancias
profit_at_optimal_y = profit_function.subs(y, optimal_y)

print(f"Ganancia en y = {optimal_y}: {profit_at_optimal_y}")

# La ganancia en (y = 37.5) es (281.25). Este resultado se obtuvo al maximizar la función de ganancias (G(y) = 15y - 0.2y^2) utilizando derivadas. 
# La interpretación económica es que la tienda maximiza sus ganancias cuando vende aproximadamente (37.5) productos, y en ese caso, la ganancia alcanza (281.25).

# La segunda derivada en (y = 37.5) es (-0.4), lo cual indica que la función de ganancias (G(y) = 15y - 0.2y^2) es cóncava hacia abajo en ese punto. 
# Dado que la segunda derivada es negativa, esto confirma que (y = 37.5) es un máximo local de la función de ganancias.
# Out:
# Derivada de la función de ganancias: 15 - 0.4*y
# Puntos críticos de la función de ganancias: [37.5000000000000]
# Segunda derivada de la función de ganancias: -0.400000000000000
# El valor de y que maximiza las ganancias es: 37.5000000000000
# Ganancia en y = 37.5000000000000: 281.250000000000

# %%
import sympy as sp  # material para revisar en autonomia

# Definimos la variable y la nueva función
y = sp.symbols('y')
profit_function = y**3 - 6*y**2 + 9*y + 1

# Derivada de la función
derivative_profit = sp.diff(profit_function, y)
print("Derivada de la función:", derivative_profit)

# Puntos críticos (donde la derivada es cero)
critical_points = sp.solve(derivative_profit, y)
print("Puntos críticos:", critical_points)

# Segunda derivada para clasificar los puntos
second_derivative = sp.diff(derivative_profit, y)
print("Segunda derivada:", second_derivative)

# Clasificamos los puntos críticos
for point in critical_points:
    concavity = second_derivative.subs(y, point)
    if concavity < 0:
        print(f"En y = {point} hay un MÁXIMO local.")
    elif concavity > 0:
        print(f"En y = {point} hay un MÍNIMO local.")
    else:
        print(f"En y = {point} la prueba de la segunda derivada es inconclusa.")
# Out:
# Derivada de la función: 3*y**2 - 12*y + 9
# Puntos críticos: [1, 3]
# Segunda derivada: 6*y - 12
# En y = 1 hay un MÁXIMO local.
# En y = 3 hay un MÍNIMO local.

# %%
# Ejercicio 3: Función Sigmoide
# Considera la función sigmoide dada por la fórmula:

# [ f(x) = \frac{1}{1 + e^{-x}} ]

# Derivada de la Función Sigmoide:
# Encuentra la derivada de (f(x)) con respecto a (x), (f'(x)).

# Puntos Críticos:
# Encuentra los puntos críticos de (f(x)) resolviendo (f'(x) = 0).

# Comportamiento Asintótico:
# Investiga el comportamiento asintótico de (f(x)) a medida que (x) tiende hacia (-\infty) y (+\infty).

# [𝑓(𝑥)=11+𝑒−𝑥]

import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Ejercicio 1: Función Sigmoide
x = sp.symbols('x')
sigmoid_function = 1 / (1 + sp.exp(-x))

# 1. Derivada de la Función Sigmoide
derivative_sigmoid = sp.diff(sigmoid_function, x)

# 2. Puntos Críticos
critical_points_sigmoid = sp.solve(derivative_sigmoid, x)

# 3. Comportamiento Asintótico
asymptotic_behavior_left = sp.limit(sigmoid_function, x, -sp.oo)
asymptotic_behavior_right = sp.limit(sigmoid_function, x, sp.oo)

# Imprimir resultados
print(f"1. Derivada de la función sigmoide: {derivative_sigmoid}")
print(f"2. Puntos críticos de la función sigmoide: {critical_points_sigmoid}")
print(f"3. Comportamiento asintótico a la izquierda: {asymptotic_behavior_left}")
print(f"   Comportamiento asintótico a la derecha: {asymptotic_behavior_right}")

# Gráfica de la función sigmoide y su derivada
x_values = np.linspace(-10, 10, 100) #para generar un conjunto de 100 valores equiespaciados entre -10 y 10
# Evalúa la función sigmoid en el conjunto de valores x_values
sigmoid_values = sp.lambdify(x, sigmoid_function, 'numpy')(x_values)
# Evalúa la derivada de la función sigmoid en el conjunto de valores x_values
derivative_values = sp.lambdify(x, derivative_sigmoid, 'numpy')(x_values)

plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(x_values, sigmoid_values, label='Sigmoide')
plt.title('Función Sigmoide')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(x_values, derivative_values, label='Derivada de la Sigmoide', color='orange')
plt.title('Derivada de la Función Sigmoide')
plt.xlabel('x')
plt.ylabel("f'(x)")
plt.legend()

plt.tight_layout()
plt.show()

# Puntos críticos de la función sigmoide: ([])

# Este resultado indica que no hay puntos críticos para la función sigmoide. Los puntos críticos son los valores de (x) donde la derivada de la función 
# es cero o no está definida. En este caso, no hay tales puntos, lo que sugiere que la función sigmoide no tiene máximos locales ni mínimos locales.

# Comportamiento asintótico a la izquierda: 0

# Esto indica que a medida que (x) tiende a menos infinito (hacia la izquierda), la función sigmoide tiende a 0. En otras palabras, la función 
# se acerca cada vez más a 0 a medida que (x) se hace muy negativo.

# Comportamiento asintótico a la derecha: 1

# Esto indica que a medida que (x) tiende a más infinito (hacia la derecha), la función sigmoide tiende a 1. En otras palabras, la función 
# se acerca cada vez más a 1 a medida que (x) se hace muy positivo.
# Out:
# 1. Derivada de la función sigmoide: exp(-x)/(1 + exp(-x))**2
# 2. Puntos críticos de la función sigmoide: []
# 3. Comportamiento asintótico a la izquierda: 0
#    Comportamiento asintótico a la derecha: 1

# %%
# Ejercicio 4: (como tarea) Se tiene un conjunto de datos que incluye el tiempo que un usuario pasa en un sitio web y si realiza o no una compra (1 si realiza una compra, 0 si no). 
# La probabilidad de realizar una compra se modela con la función sigmoide (P(t) = \frac{1}{1 + e^{-mt}}), 
# donde (t) es el tiempo en minutos y (m) es el parámetro a ajustar.

# Objetivo: Encontrar el valor de (m) que maximiza la probabilidad de compra, es decir, que minimiza la función de pérdida asociada a la regresión logística.

# Preguntas:

# Define la función de pérdida para la regresión logística.
# Utiliza métodos de optimización para encontrar el valor óptimo de (m).

import numpy as np
from scipy.optimize import minimize

# Datos de ejemplo (tiempo en minutos y compras)
time_data = np.array([10, 20, 30, 40, 50])
purchase_data = np.array([0, 0, 1, 1, 1])

# Función de pérdida para regresión logística
def logistic_loss(m):
    predictions = 1 / (1 + np.exp(-m * time_data))  # Calcula las predicciones de compra
    predictions = np.clip(predictions, 1e-15, 1 - 1e-15)  # Ajusta las predicciones para evitar log(0) y log(1)
    return -np.sum(purchase_data * np.log(predictions) + (1 - purchase_data) * np.log(1 - predictions))  # Calcula la pérdida logística

# Encontrar el valor de m que minimiza la pérdida
optimal_m_logistic = minimize(logistic_loss, x0=[1], method='L-BFGS-B').x[0]  # Encuentra el valor óptimo de m mediante minimización
#`x0=[1]` establece el punto de partida para la búsqueda del mínimo de la función de pérdida,
#y `.x[0]` extrae el valor óptimo de \(m\) encontrado por el algoritmo de optimización.


# Mostrar resultado
print("\nEjercicio 6: Ajuste de Probabilidad con Regresión Logística")
print(f"Valor de m que maximiza la probabilidad de compra: {optimal_m_logistic}")  # Muestra el valor óptimo de m
# Out:
# Ejercicio 6: Ajuste de Probabilidad con Regresión Logística
# Valor de m que maximiza la probabilidad de compra: 0.03978532139414289

# %%
# Ejercicio 5: (como tarea) La probabilidad de que un cliente realice una compra se modela con la función sigmoide (P(a) = \frac{1}{1 + e^{-ma}}), 
# donde (a) son los atributos del cliente y (m) es el parámetro a ajustar.

# Objetivo: Ajustar el modelo para maximizar las ganancias, donde las ganancias por compra son de UDs 100 y las pérdidas por una predicción incorrecta son de 50 uds

# Preguntas:

# Define la función de ganancias.
# Utiliza métodos de optimización para encontrar el valor óptimo de (m) que maximiza las ganancias.

import sympy as sp
import numpy as np
from scipy.optimize import minimize

# Definir la variable 'a' y la función sigmoide
a, m = sp.symbols('a m')
sigmoid_function = 1 / (1 + sp.exp(-m*a))

# Definir las ganancias y pérdidas por compra y predicción incorrecta
ganancia_por_compra = 100
perdida_por_prediccion_incorrecta = 50

# Función de ganancias
def ganancias(m):
    # Calcula las predicciones de compra utilizando la función sigmoide
    predicciones = 1 / (1 + np.exp(-m * atributos_clientes))
    # Ajusta las predicciones para evitar log(0) y log(1)
    predicciones = np.clip(predicciones, 1e-15, 1 - 1e-15)
    # Calcula el número esperado de compras y de predicciones incorrectas
    compras_esperadas = np.sum(predicciones)
    predicciones_incorrectas_esperadas = len(atributos_clientes) - compras_esperadas
    # Calcula las ganancias netas
    ganancias_netas = compras_esperadas * ganancia_por_compra - predicciones_incorrectas_esperadas * perdida_por_prediccion_incorrecta
    return -ganancias_netas  # Se utiliza el negativo para convertir el problema de maximización en minimización

# Atributos de los clientes (ejemplo)
atributos_clientes = np.array([0.5, 0.7, 0.3, 0.9, 0.6])

# Encontrar el valor de m que maximiza las ganancias
m_optimo = minimize(ganancias, x0=[1], method='L-BFGS-B').x[0]

# Mostrar resultado
print("\nEjercicio 5: Ajuste de Modelo para Maximizar Ganancias")
print(f"Valor óptimo de m que maximiza las ganancias: {m_optimo:.4f}")


# Cuando decimos "maximizar las ganancias", lo que queremos decir es que buscamos el valor de m que produce el mayor valor de ganancias. 
# Dado que minimize minimiza funciones, necesitamos encontrar el mínimo de la función negativa de ganancias para obtener el máximo de la función de ganancias original.

# El resultado indica que el valor óptimo de (m) que maximiza las ganancias es aproximadamente 60.1294. Esto significa que, según el modelo ajustado, 
# el parámetro (m) debe ser ajustado a este valor para maximizar las ganancias del negocio.

# En el contexto del problema, este valor óptimo indica la importancia relativa de los atributos de los clientes en el proceso de compra. Un valor más alto de 
# (m) implica que los atributos de los clientes tienen un mayor impacto en la probabilidad de realizar una compra, mientras que un valor 
# más bajo de (m) indica que estos atributos tienen un impacto menor.
# Out:
# Ejercicio 5: Ajuste de Modelo para Maximizar Ganancias
# Valor óptimo de m que maximiza las ganancias: 60.1294

# %%
# La función minimize y la función minimize_scalar son parte del paquete scipy.optimize, pero tienen diferentes propósitos y aplicaciones.

# minimize: Esta función se utiliza para minimizar una función de varias variables (es decir, una función que toma varios valores como entrada 
# y devuelve un solo valor como salida). Puede manejar problemas de optimización multidimensionales y ofrece una variedad de algoritmos de optimización 
# que se adaptan a diferentes tipos de funciones y restricciones.

# minimize_scalar: Esta función, como su nombre indica, se utiliza para minimizar una función de una sola variable (es decir, una función que toma un 
# solo valor como entrada y devuelve un solo valor como salida). Está diseñada específicamente para problemas de optimización unidimensionales y utiliza 
# métodos que son eficientes para este tipo de problemas. por ejemplo calculos de funciones cuadraticas, exponenciales y/o lineales

from scipy.optimize import minimize_scalar

# Definir la función cuadrática como una función de Python
def funcion_cuadratica(x):
    return x**2 - 6*x + 5

# Minimizar la función cuadrática utilizando minimize_scalar
resultado_minimizacion = minimize_scalar(funcion_cuadratica)

# Imprimir el resultado
print("Mínimo de la función cuadrática:", resultado_minimizacion.x)
# Out:
# Mínimo de la función cuadrática: 2.99999995559

# %%
from scipy.optimize import minimize_scalar

# Definimos la función
def profit(y):
    return -(y**3 - 6*y**2 + 9*y + 1)  # Negativo para buscar el máximo

# Buscamos el mínimo de la función negativa
result = minimize_scalar(profit)

# El máximo real está en el mismo punto pero con signo opuesto
print("y que maximiza la función:", result.x)
print("Máximo local (valor de la función):", -result.fun)

# ¿Por qué minimize_scalar encontró solo un punto?
# Porque minimize_scalar es un método numérico que solo encuentra un extremo local (mínimo o máximo), dependiendo del intervalo de búsqueda.
# Por defecto, intenta buscar globalmente, pero puede quedar atrapado en un solo punto.

# 🧠 En este caso:
# Como buscaste el mínimo de la función negativa, lo que encontraste fue el máximo local en y = 1.
# Pero a diferencia de sympy, no te devuelve todos los puntos críticos, solo uno.
# 🎯 Resumen: diferencias clave
# 🛠️ Método	🔍 Encuentra todos los extremos	🧮 Usa derivadas simbólicas	🎯 Resultado depende del punto inicial
# sympy	✅ Sí	✅ Sí	❌ No
# scipy.optimize.minimize_scalar	❌ No (solo uno)	❌ No (usa métodos numéricos)	✅ Sí
# ✅ ¿Cuál usar?
# Si querés encontrar todos los extremos (mínimos y máximos locales): sympy es ideal.
# Si solo necesitás uno (por ejemplo, el máximo más alto) y estás trabajando con datos reales o funciones más complejas: scipy es más práctico.
# Out:
# y que maximiza la función: 0.99999998519
# Máximo local (valor de la función): 5.0
