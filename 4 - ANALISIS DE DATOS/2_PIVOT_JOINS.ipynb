# %% [markdown]
# # Pivot tables y joins

# %% [markdown]
# **📊 Tablas Pivot y joins 🤝**
#
#     1. Parámetros y extracción de datos 📊
#     2. Pivot table: Contar casos a partir de un registro, Crear un panel a partir de un registro 📊
#     3. Concat 🔄
#     4. str 🔠
#     5. map 🗺️
#     6. Merge 🤝

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from IPython.display import Image
from IPython.core.display import HTML

# %% [markdown]
# ## Parámetros y extracción de datos

# %%
# Lee el archivo CSV y aplica las funciones de conversión
casos = pd.read_csv('./CSV/covid_casos.csv')

# %%
casos
# Out:
#         id_evento_caso sexo  edad edad_años_meses residencia_pais_nombre  \
# 0               672064    M  52.0            Años              Argentina
# 1               717629    F  46.0            Años              Argentina
# 2               717926    F  41.0            Años              Argentina
# 3               718029    F  52.0            Años              Argentina
# 4               718055    F  34.0            Años              Argentina
# ...                ...  ...   ...             ...                    ...
# 251368         1125696    F  72.0            Años        SIN ESPECIFICAR
# 251369         1125697    M  29.0            Años              Argentina
# 251370         1125698    F  53.0            Años              Argentina
# 251371         1125699    F  25.0            Años              Argentina
# 251372         1125701    F  71.0            Años              Argentina
#
#        residencia_provincia_nombre residencia_departamento_nombre  \
# 0                     Buenos Aires               Florencio Varela
# 1                     Buenos Aires                      Pergamino
# 2                             CABA                      COMUNA 12
# 3                     Buenos Aires                       La Plata
# 4                             CABA                SIN ESPECIFICAR
# ...                            ...                            ...
# 251368                       Chaco                   San Fernando
# 251369                Buenos Aires                   San Fernando
# 251370                        CABA                SIN ESPECIFICAR
# 251371                Buenos Aires                       La Plata
# 251372                        CABA                       COMUNA 3
#
#        carga_provincia_nombre fecha_inicio_sintomas fecha_apertura  ...  \
# 0                Buenos Aires            2020-05-29            NaN  ...
# 1                Buenos Aires            2020-01-29     2020-01-31  ...
# 2                        CABA            2020-01-23     2020-01-31  ...
# 3                Buenos Aires            2020-01-29     2020-01-31  ...
# 4                        CABA            2020-01-16     2020-01-31  ...
# ...                       ...                   ...            ...  ...
# 251368                  Chaco                   NaN     2020-06-20  ...
# 251369                   CABA                   NaN     2020-06-20  ...
# 251370                   CABA                   NaN     2020-06-20  ...
# 251371           Buenos Aires                   NaN     2020-06-20  ...
# 251372                   CABA                   NaN     2020-06-20  ...
#
#         fecha_fallecimiento asistencia_respiratoria_mecanica  \
# 0                       NaN                               NO
# 1                       NaN                               NO
# 2                       NaN                               NO
# 3                       NaN                               NO
# 4                       NaN                               NO
# ...                     ...                              ...
# 251368                  NaN                               NO
# 251369                  NaN                               NO
# 251370                  NaN                               NO
# 251371                  NaN                               NO
# 251372                  NaN                               NO
#
#        carga_provincia_id origen_financiamiento  \
# 0                       6               Público
# 1                       6               Público
# 2                       2               Público
# 3                       6               Público
# 4                       2               Privado
# ...                   ...                   ...
# 251368                 22               Público
# 251369                  2               Privado
# 251370                  2               Privado
# 251371                  6               Público
# 251372                  2               Público
#
#                                       Clasificacion clasificacion_resumen  \
# 0                                   Caso Descartado            Descartado
# 1                                   Caso Descartado            Descartado
# 2               Caso Invalidado Epidemiologicamente            Descartado
# 3               Caso Invalidado Epidemiologicamente            Descartado
# 4                                   Caso Descartado            Descartado
# ...                                             ...                   ...
# 251368                    Caso confirmado - Activo             Confirmado
# 251369  Caso sospechoso - Con muestra sin resultado            Sospechoso
# 251370                Caso Sospechoso - Sin muestra            Sospechoso
# 251371                Caso Sospechoso - Sin muestra            Sospechoso
# 251372                Caso Sospechoso - Sin muestra            Sospechoso
#
#        residencia_provincia_id  fecha_diagnostico residencia_departamento_id  \
# 0                            6         2020-06-01                        274
# 1                            6                NaN                        623
# 2                            2                NaN                         12
# 3                            6                NaN                        441
# 4                            2         2020-02-11                          0
# ...                        ...                ...                        ...
# 251368                      22         2020-06-20                        140
# 251369                       6                NaN                        749
# 251370                       2                NaN                          0
# 251371                       6                NaN                        441
# 251372                       2                NaN                          3
#
#        ultima_actualizacion
# 0                2020-06-20
# 1                2020-06-20
# 2                2020-06-20
# 3                2020-06-20
# 4                2020-06-20
# ...                     ...
# 251368           2020-06-20
# 251369           2020-06-20
# 251370           2020-06-20
# 251371           2020-06-20
# 251372           2020-06-20
#
# [251373 rows x 25 columns]

# %% [markdown]
# Si los sacamos de internet, podemos usar directamente la URL de cualquier CSV. Siempre es buena práctica guardar una copia por si en algún momento una URL deja de estar disponible.

# %% [markdown]
# ## Pivot table

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html

# %% [markdown]
# La función de `DataFrame.pivot_table` permite crear una tabla dinámica (de la misma forma que se podría hacer en una planilla de cálculo como Excel) fácilmente, eligiendo qué columnas se quieren mostrar en:
#
# * **índice (index)**: lo que se usa para abrir los datos en filas.
# * **columnas (columns)**: lo que se usa para abrir los datos en columnas.
# * **valores (values)**: las variables que se quieren abrir en filas y columnas.
#
# Y se puede elegir una o más funciones de agregación para aplicar a los valores cuando son agregados.

# %% [markdown]
# ### Contar casos a partir de un registro

# %% [markdown]
# **Casos**
#
# En el dataset de **casos** nos enfrentamos a un **registro**: el dataset es una lista de casos, donde cada fila es un "caso". No tenemos columnas con variables agregadas, tenemos la materia prima sobre la cual se construyen las estadísticas o las agregaciones de cualquier tipo.
#
# Las tablas dinámicas son una buena forma de agregar! En este caso la primera agregación obvia es _contar casos_. Tratemos de **contar la cantidad de casos de Covid por provincia**.

# %%
casos.columns
# Out:
# Index(['id_evento_caso', 'sexo', 'edad', 'edad_años_meses',
#        'residencia_pais_nombre', 'residencia_provincia_nombre',
#        'residencia_departamento_nombre', 'carga_provincia_nombre',
#        'fecha_inicio_sintomas', 'fecha_apertura', 'sepi_apertura',
#        'fecha_internacion', 'cuidado_intensivo', 'fecha_cui_intensivo',
#        'fallecido', 'fecha_fallecimiento', 'asistencia_respiratoria_mecanica',
#        'carga_provincia_id', 'origen_financiamiento', 'Clasificacion',
#        'clasificacion_resumen', 'residencia_provincia_id', 'fecha_diagnostico',
#        'residencia_departamento_id', 'ultima_actualizacion'],
#       dtype='object')

# %%
# busquemos las columnas que vamos a necesitar usar primero
casos.head(25)
# Out:
#     id_evento_caso sexo  edad edad_años_meses residencia_pais_nombre  \
# 0           672064    M  52.0            Años              Argentina
# 1           717629    F  46.0            Años              Argentina
# 2           717926    F  41.0            Años              Argentina
# 3           718029    F  52.0            Años              Argentina
# 4           718055    F  34.0            Años              Argentina
# 5           718058    F  31.0            Años              Argentina
# 6           719404    M  47.0            Años              Argentina
# 7           719405    M  30.0            Años              Argentina
# 8           720253    M  29.0            Años              Argentina
# 9           724133    M  24.0            Años              Argentina
# 10          727357    M  33.0            Años              Argentina
# 11          731171    F  73.0            Años                 Italia
# 12          731388    M  72.0            Años              Argentina
# 13          731390    F  65.0            Años              Argentina
# 14          731484    F  32.0            Años              Argentina
# 15          731537    F  12.0            Años              Argentina
# 16          731545    F  52.0            Años              Argentina
# 17          731598    F  45.0            Años              Argentina
# 18          731606    M  58.0            Años              Argentina
# 19          731608    M  22.0            Años              Argentina
# 20          731625    M  47.0            Años              Argentina
# 21          731642    M  64.0            Años              Argentina
# 22          731687    M  59.0            Años              Argentina
# 23          731890    M  21.0            Años              Argentina
# 24          732047    M  22.0            Años              Argentina
#
#    residencia_provincia_nombre residencia_departamento_nombre  \
# 0                 Buenos Aires               Florencio Varela
# 1                 Buenos Aires                      Pergamino
# 2                         CABA                      COMUNA 12
# 3                 Buenos Aires                       La Plata
# 4                         CABA                SIN ESPECIFICAR
# 5                         CABA                SIN ESPECIFICAR
# 6                 Buenos Aires                       La Plata
# 7                      Córdoba                     Río Cuarto
# 8                         CABA                      COMUNA 11
# 9                 Buenos Aires                        Quilmes
# 10                     Mendoza                     Godoy Cruz
# 11             SIN ESPECIFICAR                SIN ESPECIFICAR
# 12                Buenos Aires                       La Plata
# 13                Buenos Aires                       La Plata
# 14                        CABA                SIN ESPECIFICAR
# 15                        CABA                SIN ESPECIFICAR
# 16                Buenos Aires                     San Isidro
# 17                        CABA                       COMUNA 3
# 18                Buenos Aires                     San Isidro
# 19                        CABA                SIN ESPECIFICAR
# 20                        CABA                SIN ESPECIFICAR
# 21            Tierra del Fuego                        Ushuaia
# 22                Buenos Aires                        Escobar
# 23                     Formosa                      Pilcomayo
# 24                Buenos Aires                     San Isidro
#
#    carga_provincia_nombre fecha_inicio_sintomas fecha_apertura  ...  \
# 0            Buenos Aires            2020-05-29            NaN  ...
# 1            Buenos Aires            2020-01-29     2020-01-31  ...
# 2                    CABA            2020-01-23     2020-01-31  ...
# 3            Buenos Aires            2020-01-29     2020-01-31  ...
# 4                    CABA            2020-01-16     2020-01-31  ...
# 5                    CABA                   NaN     2020-01-31  ...
# 6                    CABA            2020-01-25     2020-02-04  ...
# 7                    CABA            2020-02-01     2020-02-04  ...
# 8                    CABA            2020-02-03     2020-02-05  ...
# 9            Buenos Aires            2020-01-30     2020-02-12  ...
# 10                Mendoza            2020-02-08     2020-02-18  ...
# 11             Santa Cruz            2020-02-23     2020-02-26  ...
# 12           Buenos Aires                   NaN     2020-02-26  ...
# 13           Buenos Aires                   NaN     2020-02-26  ...
# 14                   CABA                   NaN     2020-02-26  ...
# 15                   CABA            2020-02-25     2020-02-26  ...
# 16           Buenos Aires            2020-02-24     2020-02-26  ...
# 17                   CABA            2020-02-25     2020-02-26  ...
# 18           Buenos Aires            2020-02-25     2020-02-26  ...
# 19                   CABA            2020-02-21     2020-02-26  ...
# 20                   CABA            2020-02-24     2020-02-26  ...
# 21       Tierra del Fuego            2020-02-23     2020-02-26  ...
# 22           Buenos Aires            2020-02-21     2020-02-27  ...
# 23               San Juan            2020-02-25     2020-02-27  ...
# 24           Buenos Aires            2020-02-26     2020-02-27  ...
#
#     fecha_fallecimiento asistencia_respiratoria_mecanica carga_provincia_id  \
# 0                   NaN                               NO                  6
# 1                   NaN                               NO                  6
# 2                   NaN                               NO                  2
# 3                   NaN                               NO                  6
# 4                   NaN                               NO                  2
# 5                   NaN                               NO                  2
# 6                   NaN                               NO                  2
# 7                   NaN                               NO                  2
# 8                   NaN                               NO                  2
# 9                   NaN                               NO                  6
# 10                  NaN                               NO                 50
# 11                  NaN                               NO                 78
# 12                  NaN                               NO                  6
# 13                  NaN                               NO                  6
# 14                  NaN                               NO                  2
# 15                  NaN                               NO                  2
# 16                  NaN                               NO                  6
# 17                  NaN                               NO                  2
# 18                  NaN                               NO                  6
# 19                  NaN                               NO                  2
# 20                  NaN                               NO                  2
# 21                  NaN                               NO                 94
# 22                  NaN                               NO                  6
# 23                  NaN                               NO                 70
# 24                  NaN                               NO                  6
#
#    origen_financiamiento                                Clasificacion  \
# 0                Público                              Caso Descartado
# 1                Público                              Caso Descartado
# 2                Público          Caso Invalidado Epidemiologicamente
# 3                Público          Caso Invalidado Epidemiologicamente
# 4                Privado                              Caso Descartado
# 5                Privado                              Caso Descartado
# 6                Privado                              Caso Descartado
# 7                Público                             Otro diagnostico
# 8                Público                             Otro diagnostico
# 9                Público          Caso Invalidado Epidemiologicamente
# 10               Público                              Caso Descartado
# 11               Público  Caso sospechoso - Con muestra sin resultado
# 12               Público                              Caso Descartado
# 13               Público                              Caso Descartado
# 14               Privado          Caso Invalidado Epidemiologicamente
# 15               Privado                              Caso Descartado
# 16               Público                              Caso Descartado
# 17               Privado                              Caso Descartado
# 18               Público                              Caso Descartado
# 19               Privado                              Caso Descartado
# 20               Privado                              Caso Descartado
# 21               Público                              Caso Descartado
# 22               Privado                              Caso Descartado
# 23               Público                              Caso Descartado
# 24               Público                              Caso Descartado
#
#    clasificacion_resumen residencia_provincia_id  fecha_diagnostico  \
# 0             Descartado                       6         2020-06-01
# 1             Descartado                       6                NaN
# 2             Descartado                       2                NaN
# 3             Descartado                       6                NaN
# 4             Descartado                       2         2020-02-11
# 5             Descartado                       2         2020-02-11
# 6             Descartado                       6                NaN
# 7             Descartado                      14                NaN
# 8             Descartado                       2                NaN
# 9             Descartado                       6                NaN
# 10            Descartado                      50         2020-02-20
# 11            Sospechoso                      99                NaN
# 12            Descartado                       6         2020-02-27
# 13            Descartado                       6         2020-02-27
# 14            Descartado                       2                NaN
# 15            Descartado                       2         2020-02-28
# 16            Descartado                       6         2020-02-28
# 17            Descartado                       2         2020-02-28
# 18            Descartado                       6         2020-02-28
# 19            Descartado                       2         2020-02-28
# 20            Descartado                       2         2020-02-28
# 21            Descartado                      94         2020-02-27
# 22            Descartado                       6         2020-02-27
# 23            Descartado                      34         2020-03-02
# 24            Descartado                       6         2020-02-28
#
#    residencia_departamento_id ultima_actualizacion
# 0                         274           2020-06-20
# 1                         623           2020-06-20
# 2                          12           2020-06-20
# 3                         441           2020-06-20
# 4                           0           2020-06-20
# 5                           0           2020-06-20
# 6                         441           2020-06-20
# 7                          98           2020-06-20
# 8                          11           2020-06-20
# 9                         658           2020-06-20
# 10                         21           2020-06-20
# 11                          0           2020-06-20
# 12                        441           2020-06-20
# 13                        441           2020-06-20
# 14                          0           2020-06-20
# 15                          0           2020-06-20
# 16                        756           2020-06-20
# 17                          3           2020-06-20
# 18                        756           2020-06-20
# 19                          0           2020-06-20
# 20                          0           2020-06-20
# 21                         14           2020-06-20
# 22                        252           2020-06-20
# 23                         49           2020-06-20
# 24                        756           2020-06-20
#
# [25 rows x 25 columns]

# %%
casos.residencia_provincia_nombre.unique()
# Out:
# array(['Buenos Aires', 'CABA', 'Córdoba', 'Mendoza', 'SIN ESPECIFICAR',
#        'Tierra del Fuego', 'Formosa', 'Corrientes', 'Santa Fe',
#        'Entre Ríos', 'La Rioja', 'Río Negro', 'Chaco', 'San Luis',
#        'San Juan', 'Santa Cruz', 'Tucumán', 'Neuquén', 'La Pampa',
#        'Catamarca', 'Chubut', 'Salta', 'Santiago del Estero', 'Jujuy',
#        'Misiones'], dtype=object)

# %%
for col in casos.columns:
    if col.startswith("fecha"):
        print(col)
# Out:
# fecha_inicio_sintomas
# fecha_apertura
# fecha_internacion
# fecha_cui_intensivo
# fecha_fallecimiento
# fecha_diagnostico

# %%
# Filtra el DataFrame 'casos' para quedarse solo con los casos confirmados
casos_provincias = casos[casos.clasificacion_resumen == "Confirmado"].pivot_table(
    # Agrupa los datos por el nombre de la provincia de residencia
    index=["residencia_provincia_nombre"],
    # Cuenta la cantidad de casos usando el id de evento/caso
    values=["id_evento_caso"],
    # Usa la función de agregación 'count' para contar los casos por provincia
    aggfunc="count"
)
# Ordena el resultado por la cantidad de casos (de menor a mayor)
casos_provincias.sort_values("id_evento_caso", ascending=True)
# Out:
#                              id_evento_caso
# residencia_provincia_nombre
# La Pampa                                  6
# San Juan                                  7
# San Luis                                 12
# Jujuy                                    12
# Salta                                    21
# Santiago del Estero                      22
# Formosa                                  39
# Misiones                                 39
# Santa Cruz                               50
# Tucumán                                  57
# La Rioja                                 64
# Chubut                                   86
# Corrientes                              115
# Mendoza                                 127
# Entre Ríos                              135
# Tierra del Fuego                        136
# SIN ESPECIFICAR                         271
# Neuquén                                 303
# Santa Fe                                318
# Córdoba                                 552
# Río Negro                               675
# Chaco                                  1530
# CABA                                  18079
# Buenos Aires                          18535

# %% [markdown]
# Primer reflejo que siempre tenés que tener: controlar el resultado con algún parámetro conocido (en lo posible). En este caso, tratemos de ver si la suma de casos tiene sentido o no.

# %%
casos_provincias.id_evento_caso.sum()
# Out:
# 41191

# %% [markdown]
# En Google se muestra siempre el último dato reportado a la OMS, es un buen control
#
# https://www.google.com/search?q=casos+coronavirus+argentina&oq=casos+coronavirus&aqs=chrome.1.69i57j0l6j69i60.3332j0j7&sourceid=chrome&ie=UTF-8

# %% [markdown]
# **Ejercicio:** crear una tabla contando la cantidad de casos fallecidos y controlarla. Pista: tenés que agregar un filtro más a la tabla anterior, que use la columna "fecha_fallecimiento".

# %%
# Agrega un filtro para seleccionar solo los casos con fecha de fallecimiento no nula
casos_fallecidos = casos[casos['fecha_fallecimiento'].notnull()]

# Cuenta la cantidad de casos fallecidos
tabla_fallecidos = casos_fallecidos['id_evento_caso'].count()

# Muestra la tabla de casos fallecidos
print("Tabla de Casos Fallecidos:")
print(tabla_fallecidos)
# Out:
# Tabla de Casos Fallecidos:
# 2702

# %% [markdown]
# ### Crear un panel a partir de un registro

# %% [markdown]
# Una estructura muy común de dataset de **panel** tiene:
#
# * 1 o más variables (generalmente numéricas)
# * 1 dimensión de apertura temporal
# * 1 o más dimensiones de apertura _no temporales_
#
# Convertir registros en paneles, es un paso lógico en el procesamiento de datos primarios hacia la construcción de productos estadísticos o analíticos. Encapsula una parte del esfuerzo que conviene hacer bien de una sola vez, y luego utilizar el panel fácilmente para la mayoría de nuestras necesidades.
#
# En este caso vamos a elegir cuáles son nuestras variables de interés para **construir el panel de casos de Covid**:
#
# * provincia
# * sexo
# * fecha (tiene que haber una dimensión temporal)

# %%
# Filtra el DataFrame 'casos' para quedarse solo con los casos confirmados
casos_panel = casos[casos.clasificacion_resumen == "Confirmado"].pivot_table(
    # Agrupa los datos por provincia, nombre de provincia, sexo y fecha de diagnóstico
    index=[
        "residencia_provincia_id",
        "residencia_provincia_nombre",
        "sexo",
        "fecha_diagnostico"
    ],
    # Le dice a la función pivot_table que la columna sobre la que queremos aplicar la función de agregación es "id_evento_caso".
    # En este contexto, cada fila representa un caso, y cada caso tiene un identificador único.
    values=["id_evento_caso"],
    # aggfunc="count":
    # Indica que queremos contar cuántos valores hay en "id_evento_caso" para cada grupo definido por los índices 
    # (por ejemplo, provincia, sexo y fecha).
    # Así, obtenemos la cantidad de casos (filas) para cada combinación de los índices
    aggfunc="count"
).reset_index()  # Convierte el índice en columnas normales para facilitar el manejo
casos_panel
# Out:
#       residencia_provincia_id residencia_provincia_nombre sexo  \
# 0                           2                        CABA    F
# 1                           2                        CABA    F
# 2                           2                        CABA    F
# 3                           2                        CABA    F
# 4                           2                        CABA    F
# ...                       ...                         ...  ...
# 1722                       99             SIN ESPECIFICAR    M
# 1723                       99             SIN ESPECIFICAR    M
# 1724                       99             SIN ESPECIFICAR    M
# 1725                       99             SIN ESPECIFICAR   NR
# 1726                       99             SIN ESPECIFICAR   NR
#
#      fecha_diagnostico  id_evento_caso
# 0           2020-03-06               1
# 1           2020-03-13               1
# 2           2020-03-14               3
# 3           2020-03-15               2
# 4           2020-03-16               2
# ...                ...             ...
# 1722        2020-06-18               2
# 1723        2020-06-19               6
# 1724        2020-06-20               1
# 1725        2020-05-30               1
# 1726        2020-06-12               1
#
# [1727 rows x 5 columns]

# %% [markdown]
# **Creando un DF**

# %% [markdown]
# ## Concat

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.concat.html

# %%
casos_panel_confirmados = casos[casos.clasificacion_resumen == "Confirmado"].pivot_table(
    index=[
        "residencia_provincia_id",
        "residencia_provincia_nombre",
        "sexo",
        "fecha_diagnostico"
    ],
    values=["id_evento_caso"],
    aggfunc="count"
).reset_index()
casos_panel_confirmados.head()
# Out:
#    residencia_provincia_id residencia_provincia_nombre sexo fecha_diagnostico  \
# 0                        2                        CABA    F        2020-03-06
# 1                        2                        CABA    F        2020-03-13
# 2                        2                        CABA    F        2020-03-14
# 3                        2                        CABA    F        2020-03-15
# 4                        2                        CABA    F        2020-03-16
#
#    id_evento_caso
# 0               1
# 1               1
# 2               3
# 3               2
# 4               2

# %% [markdown]
# Ahora armemos el panel de casos fallecidos con la misma estructura.

# %%
casos_panel_fallecidos = casos[casos.clasificacion_resumen == "Confirmado"].pivot_table(
    index=[
        "residencia_provincia_id",
        "residencia_provincia_nombre",
        "sexo",
        "fecha_fallecimiento"
    ],
    values=["id_evento_caso"],
    aggfunc="count"
).reset_index()
casos_panel_fallecidos.head()
# Out:
#    residencia_provincia_id residencia_provincia_nombre sexo  \
# 0                        2                        CABA    F
# 1                        2                        CABA    F
# 2                        2                        CABA    F
# 3                        2                        CABA    F
# 4                        2                        CABA    F
#
#   fecha_fallecimiento  id_evento_caso
# 0          2020-03-25               2
# 1          2020-03-28               1
# 2          2020-04-06               1
# 3          2020-04-07               1
# 4          2020-04-09               2

# %% [markdown]
# Y ahora necesitamos modificar ambos paneles para que tengan la misma estructura, y así poder concatenarlos.
#
# * Agregar una columna para la dimensión "estado"
# * Renombrar las columnas para que sigan teniendo sentido cuando sumemos información

# %%
casos_panel_confirmados["estado"] = "confirmados"
casos_panel_confirmados = casos_panel_confirmados.rename(columns={
    "fecha_diagnostico": "fecha",
    "id_evento_caso": "casos"
})
casos_panel_confirmados.head()
# Out:
#    residencia_provincia_id residencia_provincia_nombre sexo       fecha  \
# 0                        2                        CABA    F  2020-03-06
# 1                        2                        CABA    F  2020-03-13
# 2                        2                        CABA    F  2020-03-14
# 3                        2                        CABA    F  2020-03-15
# 4                        2                        CABA    F  2020-03-16
#
#    casos       estado
# 0      1  confirmados
# 1      1  confirmados
# 2      3  confirmados
# 3      2  confirmados
# 4      2  confirmados

# %%
casos_panel_fallecidos["estado"] = "fallecidos"
casos_panel_fallecidos = casos_panel_fallecidos.rename(columns={
    "fecha_fallecimiento": "fecha",
    "id_evento_caso": "casos"
})
casos_panel_fallecidos.head()
# Out:
#    residencia_provincia_id residencia_provincia_nombre sexo       fecha  \
# 0                        2                        CABA    F  2020-03-25
# 1                        2                        CABA    F  2020-03-28
# 2                        2                        CABA    F  2020-04-06
# 3                        2                        CABA    F  2020-04-07
# 4                        2                        CABA    F  2020-04-09
#
#    casos      estado
# 0      2  fallecidos
# 1      1  fallecidos
# 2      1  fallecidos
# 3      1  fallecidos
# 4      2  fallecidos

# %% [markdown]
# Y ahora el momento de la verdad! Generemos un solo panel con todos los datos.

# %%
casos_panel2 = pd.concat([casos_panel_confirmados, casos_panel_fallecidos])
casos_panel2
# Out:
#      residencia_provincia_id residencia_provincia_nombre sexo       fecha  \
# 0                          2                        CABA    F  2020-03-06
# 1                          2                        CABA    F  2020-03-13
# 2                          2                        CABA    F  2020-03-14
# 3                          2                        CABA    F  2020-03-15
# 4                          2                        CABA    F  2020-03-16
# ..                       ...                         ...  ...         ...
# 455                       90                     Tucumán    F  2020-04-08
# 456                       90                     Tucumán    M  2020-03-29
# 457                       90                     Tucumán    M  2020-04-01
# 458                       99             SIN ESPECIFICAR    M  2020-05-25
# 459                       99             SIN ESPECIFICAR   NR  2020-06-08
#
#      casos       estado
# 0        1  confirmados
# 1        1  confirmados
# 2        3  confirmados
# 3        2  confirmados
# 4        2  confirmados
# ..     ...          ...
# 455      1   fallecidos
# 456      1   fallecidos
# 457      1   fallecidos
# 458      1   fallecidos
# 459      1   fallecidos
#
# [2187 rows x 6 columns]

# %% [markdown]
# ## .str

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.html

# %% [markdown]
# Todas las columnas (Series) de un data frame tienen diferentes métodos asociados que se pueden utilzar para hacer transformaciones rápidamente.
#
# Hay un grupo de ellos accesible a través del atributo `str` (`Series.str`) que implementa las funciones usuales de Python sobre strings, para una columna de valores de texto.

# %% [markdown]
# ### .str.replace()

# %% [markdown]
# Si queremos graficar la evolución de casos por sexo, pero queremos una leyenda con la palabra completa, tal vez necesitemos reemplazar los valores usados en el dataset por otros.

# %%
casos_panel2.head()
# Out:
#    residencia_provincia_id residencia_provincia_nombre sexo       fecha  \
# 0                        2                        CABA    F  2020-03-06
# 1                        2                        CABA    F  2020-03-13
# 2                        2                        CABA    F  2020-03-14
# 3                        2                        CABA    F  2020-03-15
# 4                        2                        CABA    F  2020-03-16
#
#    casos       estado
# 0      1  confirmados
# 1      1  confirmados
# 2      3  confirmados
# 3      2  confirmados
# 4      2  confirmados

# %%
casos_panel2["sexo"] = casos_panel2.sexo.str.replace(
    "F", "Femenino"
).replace(
    "M", "Masculino"
).replace(
    "NR", "No responde"
)

# %%
casos_panel2.sexo.value_counts()
# Out:
# sexo
# Masculino      1124
# Femenino        977
# No responde      86
# Name: count, dtype: int64

# %%
casos_panel2.head()
# Out:
#    residencia_provincia_id residencia_provincia_nombre      sexo       fecha  \
# 0                        2                        CABA  Femenino  2020-03-06
# 1                        2                        CABA  Femenino  2020-03-13
# 2                        2                        CABA  Femenino  2020-03-14
# 3                        2                        CABA  Femenino  2020-03-15
# 4                        2                        CABA  Femenino  2020-03-16
#
#    casos       estado
# 0      1  confirmados
# 1      1  confirmados
# 2      3  confirmados
# 3      2  confirmados
# 4      2  confirmados

# %% [markdown]
# ## .map

# %% [markdown]
#  el método `.map()`, al que se le puede pasar un diccionario con los reemplazos.

# %%
casos_panel2["sexo"] = casos_panel2.sexo.map({
    "Masculino": "Masc",
    "Femenino": "Fem",
    "No responde": "Sin especificar"
})

# %%
casos_panel2.sexo.value_counts()
# Out:
# sexo
# Masc               1124
# Fem                 977
# Sin especificar      86
# Name: count, dtype: int64

# %%
casos_panel2.head()
# Out:
#    residencia_provincia_id residencia_provincia_nombre sexo       fecha  \
# 0                        2                        CABA  Fem  2020-03-06
# 1                        2                        CABA  Fem  2020-03-13
# 2                        2                        CABA  Fem  2020-03-14
# 3                        2                        CABA  Fem  2020-03-15
# 4                        2                        CABA  Fem  2020-03-16
#
#    casos       estado
# 0      1  confirmados
# 1      1  confirmados
# 2      3  confirmados
# 3      2  confirmados
# 4      2  confirmados

# %% [markdown]
# ## Merge - TAREA INDIVIDUAL :)

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html

# %% [markdown]
# "Mergear", "joinear" o cruzar dos datasets, implica elegir una o más columnas que estos tengan en común y utilizarlas para cruzar ambas tablas en base a la coincidencia de valores entre ambas. Existen varios tipos de _joins_ según cuál es el resultado que nos interesa obtener al final con la cruza:
#
# * **left join**: preserva el 100% de las filas que tiene la tabla _de la izquierda_ del merge, y agrega las columnas del dataset _de la derecha_ con los valores (cuando hay una coincidencia) o las llena con valores nulos (cuando no hay coincidencia). Si el dataset de la derecha tiene valores para filas que no están presentes en el dataset de la izquierda, simplemente no se utilizan. El dataset resultado tiene la misma cantidad de filas que el dataset de la izquierda.
# * **right join**: es igual que el anterior, pero se preservan las filas del dataset de la derecha en lugar de las del de la izquierda.
# * **inner join**: sólo se mantienen aquellas filas que coinciden _en ambos datasets_. Si alguna fila no tiene coincidencia en uno de los dos, se descarta. El dataset final tiene igual cantidad o menos filas que el dataset más grande.
# * **outer join**: se preservan todas las filas. Si hay coincidencia, se cruzan, y si no hay coincidencia se apilan llenando con valores nulos.
#
# El tipo de join más común que van a utilizar la mayoría de las veces es el **left join**, cuyo caso de uso es "tengo una tabla, y quiero enriquecerla con nuevas columnas".

# %% [markdown]
# Ahora, queremos calcular y graficar un indicador utilizado en algunos análisis que es la cantidad de testeos sobre la cantidad de casos confirmados.
#
# Este indicador nos dice cuántos tests están siendo necesarios para identificar cada caso positivo de Covid. Para esto vamos a necesitar cruzar los datos de **determinaciones** con los de **casos**.
#
# Hasta ahora nuestro panel tenía una sola variable! Pero ya es hora de que le agreguemos otra: `tests`.

# %%
casos_panel2
# Out:
#      residencia_provincia_id residencia_provincia_nombre             sexo  \
# 0                          2                        CABA              Fem
# 1                          2                        CABA              Fem
# 2                          2                        CABA              Fem
# 3                          2                        CABA              Fem
# 4                          2                        CABA              Fem
# ..                       ...                         ...              ...
# 455                       90                     Tucumán              Fem
# 456                       90                     Tucumán             Masc
# 457                       90                     Tucumán             Masc
# 458                       99             SIN ESPECIFICAR             Masc
# 459                       99             SIN ESPECIFICAR  Sin especificar
#
#           fecha  casos       estado
# 0    2020-03-06      1  confirmados
# 1    2020-03-13      1  confirmados
# 2    2020-03-14      3  confirmados
# 3    2020-03-15      2  confirmados
# 4    2020-03-16      2  confirmados
# ..          ...    ...          ...
# 455  2020-04-08      1   fallecidos
# 456  2020-03-29      1   fallecidos
# 457  2020-04-01      1   fallecidos
# 458  2020-05-25      1   fallecidos
# 459  2020-06-08      1   fallecidos
#
# [2187 rows x 6 columns]

# %% [markdown]
# ¿Cómo hacemos esto? Para cruzar (o "joinear") un dataset con otro, necesitamos definir un conjunto de columnas común por el cual hacerlo, esto a veces se llama **clave primaria** (o "primary key").
#
# La clave primaria de una tabla es el conjunto de columnas necesarias para identificar a una sola fila de la tabla. Si miramos nuestro último panel, vemos que necesitamos las columnas **provincia**, **sexo**, **fecha** y **estado**.

# %%
# Ruta al archivo CSV en Colab
ruta_archivo = './csv/covid_determinaciones.csv'

# Leer el archivo CSV con pandas
determinaciones = pd.read_csv(ruta_archivo)

# Mostrar las primeras filas del conjunto de datos
print(determinaciones.head())
# Out:
#         fecha     provincia  codigo_indec_provincia  departamento  \
# 0  2020-02-11          CABA                       2      COMUNA 4
# 1  2020-02-20          CABA                       2      COMUNA 4
# 2  2020-02-20  Buenos Aires                       6  Bahía Blanca
# 3  2020-02-27          CABA                       2      COMUNA 4
# 4  2020-02-28          CABA                       2      COMUNA 4
#
#    codigo_indec_departamento         localidad  codigo_indec_localidad  \
# 0                          4  PARQUE PATRICIOS                      10
# 1                          4  PARQUE PATRICIOS                      10
# 2                         56      BAHIA BLANCA                      10
# 3                          4  PARQUE PATRICIOS                      10
# 4                          4  PARQUE PATRICIOS                      10
#
#   origen_de_financiamiento      tipo ultima_actualizacion  total  positivos
# 0                  Público  Nacional           2020-06-20      2        NaN
# 1                  Público  Nacional           2020-06-20      1        NaN
# 2                  Privado   Privado           2020-06-20      1        NaN
# 3                  Público  Nacional           2020-06-20      4        NaN
# 4                  Público  Nacional           2020-06-20     10        NaN

# %%
determinaciones
# Out:
#            fecha         provincia  codigo_indec_provincia  departamento  \
# 0     2020-02-11              CABA                       2      COMUNA 4
# 1     2020-02-20              CABA                       2      COMUNA 4
# 2     2020-02-20      Buenos Aires                       6  Bahía Blanca
# 3     2020-02-27              CABA                       2      COMUNA 4
# 4     2020-02-28              CABA                       2      COMUNA 4
# ...          ...               ...                     ...           ...
# 6732  2020-06-20          Santa Fe                      82       Rosario
# 6733  2020-06-20          Santa Fe                      82       Rosario
# 6734  2020-06-20  Tierra del Fuego                      94       Ushuaia
# 6735  2020-06-20           Tucumán                      90     Cruz Alta
# 6736  2020-06-20           Tucumán                      90       Capital
#
#       codigo_indec_departamento              localidad  \
# 0                             4       PARQUE PATRICIOS
# 1                             4       PARQUE PATRICIOS
# 2                            56           BAHIA BLANCA
# 3                             4       PARQUE PATRICIOS
# 4                             4       PARQUE PATRICIOS
# ...                         ...                    ...
# 6732                         84                ROSARIO
# 6733                         84                ROSARIO
# 6734                         14                USHUAIA
# 6735                         14     BANDA DEL RIO SALI
# 6736                         84  SAN MIGUEL DE TUCUMAN
#
#       codigo_indec_localidad origen_de_financiamiento        tipo  \
# 0                         10                  Público    Nacional
# 1                         10                  Público    Nacional
# 2                         10                  Privado     Privado
# 3                         10                  Público    Nacional
# 4                         10                  Público    Nacional
# ...                      ...                      ...         ...
# 6732                     270                  Privado     Privado
# 6733                     270                  Público   Municipal
# 6734                      20                  Público  Provincial
# 6735                      20                  Público  Provincial
# 6736                      10                  Público  Provincial
#
#      ultima_actualizacion  total  positivos
# 0              2020-06-20      2        NaN
# 1              2020-06-20      1        NaN
# 2              2020-06-20      1        NaN
# 3              2020-06-20      4        NaN
# 4              2020-06-20     10        NaN
# ...                   ...    ...        ...
# 6732           2020-06-20      1        1.0
# 6733           2020-06-20     19        3.0
# 6734           2020-06-20      3        NaN
# 6735           2020-06-20      2        NaN
# 6736           2020-06-20      4        NaN
#
# [6737 rows x 12 columns]

# %% [markdown]
# Sin embargo el panel de "determinaciones" sólo comparte las columnas **fecha** y **provincia**, así que necesitamos generar dos paneles con esa clave primaria para poder cruzarlos.

# %%
casos_confirmados_provincias = casos_panel2[
    casos_panel2.estado == "confirmados"
].pivot_table(
    index=["residencia_provincia_id", "fecha"],
    values="casos",
    aggfunc="sum"
).reset_index()

casos_confirmados_provincias
# Out:
#       residencia_provincia_id       fecha  casos
# 0                           2  2020-03-03      1
# 1                           2  2020-03-06      4
# 2                           2  2020-03-07      1
# 3                           2  2020-03-08      2
# 4                           2  2020-03-09      1
# ...                       ...         ...    ...
# 1006                       99  2020-06-16     11
# 1007                       99  2020-06-17     14
# 1008                       99  2020-06-18      9
# 1009                       99  2020-06-19     13
# 1010                       99  2020-06-20      2
#
# [1011 rows x 3 columns]

# %% [markdown]
# Siempre recuerden controlar el resultado!

# %%
casos_confirmados_provincias.casos.sum()
# Out:
# 41191

# %% [markdown]
# Ahora hacemos un panel de determinaciones con la misma estructura.

# %%
determinaciones_panel = determinaciones.pivot_table(
    index=["codigo_indec_provincia", "fecha"],
    values="total",
    aggfunc="sum"
).reset_index()

determinaciones_panel
# Out:
#       codigo_indec_provincia       fecha  total
# 0                          2  2020-02-11      2
# 1                          2  2020-02-20      1
# 2                          2  2020-02-27      4
# 3                          2  2020-02-28     10
# 4                          2  2020-03-02      5
# ...                      ...         ...    ...
# 1885                      94  2020-06-20      3
# 1886                      99  2020-05-22      1
# 1887                      99  2020-06-03      1
# 1888                      99  2020-06-12      1
# 1889                      99  2020-06-14      2
#
# [1890 rows x 3 columns]

# %%
determinaciones_panel.total.sum()
# Out:
# 280326

# %% [markdown]
# ##TAREA

# %% [markdown]
# Llegó el momento del join! Recordemos que el objetivo es terminar con un solo panel, donde haya ahora dos variables: **casos** y **tests** ; con apertura por las dos dimensiones que comparten los datasets: **provincia** y **fecha**.
#
# Para esto vamos a usar la función `DataFrame.merge()`.

# %%
# Convertir las columnas a string en ambos DataFrames
casos_confirmados_provincias['residencia_provincia_id'] = casos_confirmados_provincias['residencia_provincia_id'].astype(str)
determinaciones_panel['codigo_indec_provincia'] = determinaciones_panel['codigo_indec_provincia'].astype(str)

# Realizar la fusión después de la conversión
casos_tests = casos_confirmados_provincias.merge(
    determinaciones_panel,
    left_on=["residencia_provincia_id", "fecha"],
    right_on=["codigo_indec_provincia", "fecha"]
)

casos_tests
# Out:
#     residencia_provincia_id       fecha  casos codigo_indec_provincia  total
# 0                         2  2020-03-03      1                      2      8
# 1                         2  2020-03-06      4                      2     11
# 2                         2  2020-03-07      1                      2      9
# 3                         2  2020-03-08      2                      2     28
# 4                         2  2020-03-09      1                      2     13
# ..                      ...         ...    ...                    ...    ...
# 879                      94  2020-05-26      1                     94     23
# 880                      99  2020-05-22      5                     99      1
# 881                      99  2020-06-03      4                     99      1
# 882                      99  2020-06-12     10                     99      1
# 883                      99  2020-06-14      8                     99      2
#
# [884 rows x 5 columns]

# %% [markdown]
# Bien! Noten que si la columna coincide en nombre, quedará una sola columna, pero si los nombres son diferentes tendremos una columna duplicada (que no queremos). Además deberíamos clarificar el nombre de la segunda variable.

# %%
casos_tests = casos_tests.drop(
    columns=["codigo_indec_provincia"]
)
casos_tests
# Out:
#     residencia_provincia_id       fecha  casos  total
# 0                         2  2020-03-03      1      8
# 1                         2  2020-03-06      4     11
# 2                         2  2020-03-07      1      9
# 3                         2  2020-03-08      2     28
# 4                         2  2020-03-09      1     13
# ..                      ...         ...    ...    ...
# 879                      94  2020-05-26      1     23
# 880                      99  2020-05-22      5      1
# 881                      99  2020-06-03      4      1
# 882                      99  2020-06-12     10      1
# 883                      99  2020-06-14      8      2
#
# [884 rows x 4 columns]

# %%
casos_tests = casos_tests.rename(
    columns={"total": "tests"}
)
casos_tests
# Out:
#     residencia_provincia_id       fecha  casos  tests
# 0                         2  2020-03-03      1      8
# 1                         2  2020-03-06      4     11
# 2                         2  2020-03-07      1      9
# 3                         2  2020-03-08      2     28
# 4                         2  2020-03-09      1     13
# ..                      ...         ...    ...    ...
# 879                      94  2020-05-26      1     23
# 880                      99  2020-05-22      5      1
# 881                      99  2020-06-03      4      1
# 882                      99  2020-06-12     10      1
# 883                      99  2020-06-14      8      2
#
# [884 rows x 4 columns]

# %% [markdown]
# ¿Por qué no usamos concat en lugar de merge, y agregamos una columna que se llame `variable` y tenga los valores "casos" y "tests"?
#
# Esto también hubiera sido una estructura de panel posible, con sus ventajas y desventajas. Si tuviéramos una _gran cantidad_ de variables tal vez es mejor elegir esa estructura de dataset **más vertical**, pero si tenemos pocas, tal vez es mejor que cada variable sea una columna.
#
# ¿No son casos confirmados y casos fallecidos variables distintas también? Sí, podría pensarse así. Pero en este caso sí es más claro que se puede modelar como una variable **casos** con una dimensión de apertura que es el **estado** del caso.

# %% [markdown]
# Ahora queremos calcular una nueva variable: tests x caso confirmado.

# %%
casos_tests["tests_por_confirmado"] = casos_tests.tests / casos_tests.casos

casos_tests
# Out:
#     residencia_provincia_id       fecha  casos  tests  tests_por_confirmado
# 0                         2  2020-03-03      1      8                  8.00
# 1                         2  2020-03-06      4     11                  2.75
# 2                         2  2020-03-07      1      9                  9.00
# 3                         2  2020-03-08      2     28                 14.00
# 4                         2  2020-03-09      1     13                 13.00
# ..                      ...         ...    ...    ...                   ...
# 879                      94  2020-05-26      1     23                 23.00
# 880                      99  2020-05-22      5      1                  0.20
# 881                      99  2020-06-03      4      1                  0.25
# 882                      99  2020-06-12     10      1                  0.10
# 883                      99  2020-06-14      8      2                  0.25
#
# [884 rows x 5 columns]

# %%
from matplotlib import pyplot as plt
casos_tests['tests_por_confirmado'].plot(kind='hist', bins=20, title='tests_por_confirmado')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# **`Usemos Plotly Express!!!`**

# %%
import pandas as pd
import plotly.express as px

# xon la columna llamada 'casos_confirmados hacemos la sumatoria
casos_confirmados_por_fecha = casos_tests.groupby('fecha')['tests_por_confirmado'].sum().reset_index()

# Crear el gráfico de evolución de tests por confirmado por fecha
fig = px.line(casos_confirmados_por_fecha, x='fecha', y='tests_por_confirmado', title='Evolución de Tests por Confirmado',
              labels={'tests_por_confirmado': 'Tests por Confirmado', 'fecha': 'Fecha'})

# Mostrar el gráfico
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="21724dc9-3179-4dac-8007-bfe839952ba0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("21724dc9-3179-4dac-8007-bfe839952ba0")) {                    Plotly.newPlot(                        "21724dc9-3179-4dac-8007-bfe839952ba0",                        [{"hovertemplate":"Fecha=%{x}\u003cbr\u003eTests por Confirmado=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2020-03-03","2020-03-06","2020-03-07","2020-03-08","2020-03-09","2020-03-10","2020-03-11","2020-03-12","2020-03-13","2020-03-14","2020-03-15","2020-03-16","2020-03-17","2020-03-18","2020-03-19","2020-03-20","2020-03-21","2020-03-22","2020-03-23","2020-03-24","2020-03-25","2020-03-26","2020-03-27","2020-03-28","2020-03-29","2020-03-30","2020-03-31","2020-04-01","2020-04-02","2020-04-03","2020-04-04","2020-04-05","2020-04-06","2020-04-07","2020-04-08","2020-04-09","2020-04-10","2020-04-11","2020-04-12","2020-04-13","2020-04-14","2020-04-15","2020-04-16","2020-04-17","2020-04-18","2020-04-19","2020-04-20","2020-04-21","2020-04-22","2020-04-23","2020-04-24","2020-04-25","2020-04-26","2020-04-27","2020-04-28","2020-04-29","2020-04-30","2020-05-01","2020-05-02","2020-05-03","2020-05-04","2020-05-05","2020-05-06","2020-05-07","2020-05-08","2020-05-09","2020-05-10","2020-05-11","2020-05-12","2020-05-13","2020-05-14","2020-05-15","2020-05-16","2020-05-17","2020-05-18","2020-05-19","2020-05-20","2020-05-21","2020-05-22","2020-05-23","2020-05-24","2020-05-25","2020-05-26","2020-05-27","2020-05-28","2020-05-29","2020-05-30","2020-05-31","2020-06-01","2020-06-02","2020-06-03","2020-06-04","2020-06-05","2020-06-06","2020-06-07","2020-06-08","2020-06-09","2020-06-10","2020-06-11","2020-06-12","2020-06-13","2020-06-14","2020-06-15","2020-06-16","2020-06-17","2020-06-18","2020-06-19","2020-06-20"],"xaxis":"x","y":[8.0,2.75,9.0,14.0,13.0,28.0,17.0,46.0,28.666666666666668,9.8,11.428571428571429,35.333333333333336,21.5,11.882352941176471,48.78787878787879,26.425,18.806878306878307,20.877272727272725,43.81089743589744,39.36866359447005,50.79642857142857,78.63174603174603,40.45760869565217,42.41991341991342,39.92221719457014,54.64520202020202,51.66267066267066,108.93908045977011,159.97129981024668,176.90330086580087,159.7274817136886,118.15961538461539,236.27637729895793,222.07664835164837,191.99120082815736,196.96904761904761,204.61515151515152,290.7647058823529,257.4142857142857,349.38501353718743,218.54563492063494,338.19089093701996,216.63297610248827,305.5577380952381,348.69452833418933,310.22078272604585,525.1458333333334,253.96037200778528,327.6478487614081,339.4402543626146,468.938709038709,483.17065897065896,195.40151515151516,258.30329123612705,239.4974398361495,348.37721598002497,140.45610630504248,100.65490791458284,101.884410801964,149.96820737615388,259.196691277003,357.14069264069263,293.5077755240027,231.951434052309,161.41231178731178,140.55582956457147,72.04596918233281,180.81634123596496,228.89034395159362,109.98157894736843,181.02501725327812,63.587494135585274,168.77160760143812,72.88020015698586,92.96783268872655,153.84213601955537,335.6022823620092,440.5345389416939,195.24512787448955,341.7697220321437,135.74907079297583,266.4635100083199,108.48520044993279,507.59719908690056,457.5079413829414,428.3056636188923,436.96315390396546,116.40468490878939,205.23528772731086,371.0260504201681,115.80800168563988,237.3725729082289,345.8029554807878,180.37660647796133,42.42198380228771,437.5046004481648,530.5929630673022,336.3013545452728,390.55953022910427,477.73804869940125,413.1464991646376,249.31076952051137,115.3750518 ...
